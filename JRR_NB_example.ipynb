# %% [markdown]
# This is an example of using the ipython notebook as documentation of scientific workflow.  A real scientific notebook.

# %%
import numpy as np
from astropy.io import fits

# %%
from astropy.utils.data import download_file
image_file = download_file('http://data.astropy.org/tutorials/FITS-images/HorseHead.fits', cache=True )
hdulist = fits.open(image_file)
hdulist.info()
im = hdulist[0].data
im.shape
# Out:
# Filename: /Users/jrrigby1/.astropy/cache/download/2c9202ae878ecfcb60878ceb63837f5f
# No.    Name         Type      Cards   Dimensions   Format
# 0    PRIMARY     PrimaryHDU     161   (891, 893)   int16
# 1    er.mask     TableHDU        25   1600R x 4C   [F6.2, F6.2, F6.2, F6.2]
# (893, 891)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.imshow(im, cmap='gray')

# %%
foo = np.array([3,3,4,5])
print foo
type(foo)
# Out:
# [3 3 4 5]
# numpy.ndarray
